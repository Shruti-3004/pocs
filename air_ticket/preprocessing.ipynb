# %%
import cv2
import os

image = 'C:\\air_ticket\\delimiters2\\Yatra_AAAIN233676183_20.09.2022_page0.jpg'
img = cv2.imread(image)

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

k = 5
result = 255*(img/255)**k

cv2.imwrite('result.jpg', result)

command = 'tesseract result.jpg stdout -l eng --psm 4'
print(os.popen(command).read())
# Out:
# =
#
# Original for recipient
#
# 2
#
# ‘or Business
#
# Invoice Category
# B26
#
# GSTIN: 36AAACA0313P2ZV
# PAN Card No. : AAACA0313P
#
# Yatra for Business Private Limited
#
# 301, Dev Dhanuka Prestige, Plot No-8,
#
# Corporate Identity No. :
# U72900DL1962PTC003735
#
# Road No -12, Banjara Hills,
#
# HYDERABAD-500034,
# INDIA
#
# Entity
#
# Address
#
# State Code
# GSTIN
# BookingDetails:
# Booking Ref.
# Invoice No. :
# Booking Type
# Trip Id
#
# HSN - 998551
# TELANGANA,
#
# Tax Invoice - Air (Domestic!
# : COMAKEIT SOFTWARE PVT LTD
# : PHASE - III, ROAD NO. 92 JUBILEE HILLS,PLOT NO. 564/A39,, HYDERABAD-500033, Telangana
# 136 Place of Supply : Telangana
# : 36AACCC8032H1ZT PAN Number : AACCC8032H
# 1 CT6142674 Booking Date : : 12 Sep 2022
# 1 AAAIN233676183 Invoice Date : : 20 SEP 2022
# : Official
# + TA1209220120464 Im Number 3
# 577903ab7790bc3 12ab5e06e849a
# 8e6d57d87 5cf1 60fa573503009e03
# d908da1
#
# Sector Travel Date Ticket Number | PNR No.
#
# ...

# %%
image = 'C:\\air_ticket\\delimiters2\\Yatra_AAAIN233676564_26.09.2022_page0.jpg'
command = 'tesseract {} stdout -l eng --psm 4'.format(image)
print(os.popen(command).read())
# Out:
#
#
#
#
#
#
# riginal for recipient
#
# yatye
#
# for Business
#
# Yatra for Business Private Limited
#
# 301, Dev Dhanuka Prestige, Plot No -8,
#
# Road No -12, Banjara Hills,
#
# HYDERABAD-500034, TELANGANA,
#
# INDIA
#
# Entity
#
# Address
#
# State Code
# GSTIN
# BookingDetails:
# Booking Ref.
# Invoice No.
#
# Booking Type
# Trip Id
#
# Pax Name |
# Mr Surya Teja |
# Madastu(ADT,
#
#
#
#
#
#
#
#
#
#
#
# Sector
# GOI-HYD
#
#
#
# Air Asia India-15-974)
#
# Invoice Category |
# B2B,
#
# GSTIN: 36AAACA0313P2ZV
# PAN Card No. : AAACA0313P
#
# Corporate Identity No. :
# U72900DL1962PTC003735
#
# HSN - 998551 |
#
#
#
#
#
# Tax Invoice - Air (Domestic)
# COMAKEIT SOFTWARE PVT LTD.
# PHASE - III, ROAD NO. 92JUBILEE HILLS,PLOT NO. 564/A39,, HYDERABAD-500033, Telangana
#
# 36 Place of Supply Telangana
# 36AACCC8032H1ZT PAN Number AACCC8032H
# CT6142674 Booking Date 12 Sep 2022
# AAAIN233676564 , Invoice Date 26 SEP 2022
#
# Official
# TA1209220120464 Irn Number
#
# ...
